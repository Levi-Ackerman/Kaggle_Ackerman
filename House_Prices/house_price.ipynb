# %% [markdown]
# ## 房价预测

# %%
import pandas as pd

# 读取数据
train = pd.read_csv('./data/train.csv', sep=',')
train_id = train.pop('Id')
print('train shape:', train.shape, ', train id shape:', train_id.shape)
# Out:
# train shape: (1460, 80) , train id shape: (1460,)

# %%
import seaborn as sb
import matplotlib.pyplot as plt
% matplotlib inline

# 特征协方差热力图
corrmat = train.corr()
f, ax = plt.subplots(figsize=(12, 9))
sb.heatmap(corrmat, vmax=0.8, square=True)
